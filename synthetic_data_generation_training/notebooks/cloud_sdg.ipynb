# %% [markdown]
# # Part 1: Synthetic Data Generation and Training Workflow with Warehouse Sim Ready Assets
#
# This notebook is the first part of the SDG and Training Workflow. We will be focusing on generating Synthetic Data for our use case
#
# A high level overview of the steps:
# * Pulling Isaac Sim Docker Container
# * Using Replicator API for Data Generation with Domain Randomization

# %% [markdown]
# ### Table of Contents
#
# This notebook shows provides an overview of generating synthetic data using Warehouse Sim Ready assets with Isaac Sim and Omniverse Replicator. We will generate data for the `palletjack` class of objects.
#
# 1. [Set up Isaac Sim via Docker Container](#head-1)
# 2. [Generate Data for Detecting Palletjacks](#head-2)
# 3. [Deeper dive into SDG script](#head-3)

# %% [markdown]
# ## 1. Set up Isaac Sim: Docker Container Installation <a class="anchor" id="head-1"></a>
#
# ### This step can be skipped if the Isaac Sim Docker container has already been set up on your Cloud/Remote Instance
#
# * Follow the [instructions](https://docs.omniverse.nvidia.com/isaacsim/2022.2.1/install_container.html) for Isaac Sim Container Installation
# * Ensure that `docker run` command on Step 7 works as expected and you are able to enter the container.
#
# We will use `./python.sh` in the container to run our SDG script. Please make sure you exit the container before running the next cells

# %% [markdown]
# ## 2. Generate Data for Detecting Palletjacks  <a class="anchor" id="head-2"></a>
#
# * We can find the Palletjack USDs in the Warehouse Sim Ready asset collection (`http://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/DigitalTwin/Assets/Warehouse/Equipment/Pallet_Trucks`)
# * First, we will mount our current local directory while running the docker container. This will ensure that we can run our scripts inside the Isaac Sim container. Data generated in the container will also be saved in this mounted directory.

# %%
import os

# This is the directory which will be mounted into the Isaac Sim container. Make sure <path_to_repo_cloned> is updated correctly
os.environ["MOUNT_DIR"]=os.path.join(os.path.expanduser("~/Documents/synthetic_data_generation_training_workflow"), "palletjack_sdg")
os.environ["LOCAL_PROJECT_DIR"]=os.path.dirname(os.getcwd())
#os.environ["MOUNT_DIR"] = os.path.join(os.getenv("LOCAL_PROJECT_DIR"), "palletjack_sdg")
print(os.getenv("MOUNT_DIR"))
# Out:
# /home/elliemcintosh/Documents/synthetic_data_generation_training_workflow/palletjack_sdg

# %%
# verify the directory exists
print(os.path.exists(os.environ["MOUNT_DIR"]))
# Out:
# True

# %%
print(os.getenv("MOUNT_DIR"))
# Out:
# /home/elliemcintosh/Documents/synthetic_data_generation_training_workflow/palletjack_sdg

# %%
# Make sure the MOUNT_DIR location is correct, it shold have the scripts needed for SDG there

# !docker run --name isaac-sim --entrypoint bash -it --gpus all -e "ACCEPT_EULA=Y" --rm --network=host \
    -v ~/docker/isaac-sim/cache/kit:/isaac-sim/kit/cache/Kit:rw \
    -v ~/docker/isaac-sim/cache/ov:/root/.cache/ov:rw \
    -v ~/docker/isaac-sim/cache/pip:/root/.cache/pip:rw \
    -v ~/docker/isaac-sim/cache/glcache:/root/.cache/nvidia/GLCache:rw \
    -v ~/docker/isaac-sim/cache/computecache:/root/.nv/ComputeCache:rw \
    -v ~/docker/isaac-sim/logs:/root/.nvidia-omniverse/logs:rw \
    -v ~/docker/isaac-sim/data:/root/.local/share/ov/data:rw \
    -v ~/docker/isaac-sim/documents:/root/Documents:rw \
    -v $MOUNT_DIR:/isaac-sim/palletjack_sdg \
    nvcr.io/nvidia/isaac-sim:2022.2.1 \
    ./palletjack_sdg/palletjack_datagen.sh
    
# Make sure $MOUNT_DIR is set correctly from the cell above
# Out:
# Starting Data Generation
# /isaac-sim
# [Warning] [omni.isaac.kit.simulation_app] Modules: ['omni.isaac.kit.app_framework'] were loaded before SimulationApp was started and might not be loaded correctly.
# [Warning] [omni.isaac.kit.simulation_app] Please check to make sure no extra omniverse or pxr modules are imported before the call to SimulationApp(...)
# Starting kit application with the following args:  ['/isaac-sim/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/isaac-sim/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/isaac-sim/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=960', '--/app/renderer/resolution/height=544', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=True', '--ext-folder', '/isaac-sim/exts', '--ext-folder', '/isaac-sim/apps', '--/physics/cudaDevice=0', '--portable', '--no-window', '--allow-root']
# Passing the following args to the base kit application:  ['--headless', 'True', '--height', '544', '--width', '960', '--num_frames', '2000', '--distractors', 'warehouse', '--data_dir', '/isaac-sim/palletjack_sdg/palletjack_data/distractors_warehouse']
# [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [Info] [carb] Logging to file: /isaac-sim/kit/logs/Kit/Isaac-Sim/2022.2/kit_20260508_051112.log
# 2026-05-08 05:11:12 s] [Warning] [omni.ext.plugin] [ext: omni.sensors.nv.lidar] Extensions config 'extension.toml' doesn't exist '/isaac-sim/exts/omni.sensors.nv.lidar' or '/isaac-sim/exts/omni.sensors.nv.lidar/config'
# 2026-05-08 05:11:12 s] [Warning] [omni.ext.plugin] [ext: omni.sensors.nv.radar] Extensions config 'extension.toml' doesn't exist '/isaac-sim/exts/omni.sensors.nv.radar' or '/isaac-sim/exts/omni.sensors.nv.radar/config'
# [0.254s] [ext: omni.stats-0.0.0] startup
# [0.369s] [ext: omni.rtx.shadercache-1.0.0] startup
# [0.387s] [ext: omni.assets.plugins-0.0.0] startup
# [0.404s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.512s] [ext: carb.windowing.plugins-1.0.0] startup
# 2026-05-08 05:11:13 s] [Warning] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2026-05-08 05:11:13 s] [Warning] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.3]) (impl: carb.windowing-glfw.plugin)
# [0.521s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 590.48.01     | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA L4                        | Yes: 0 |     | 23034   MB | 10de      | 0          |
# |     |                                  |        |     |            | 27b8      | 95180548.. |
# |=============================================================================================|
# | OS: Linux omniverse-vm-central, Version: 6.8.0-1053-gcp
# | Processor:            Intel(R) Xeon(R) CPU @ 2.20GHz | Cores: Unknown | Logical: 12
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 48171 | Free Memory: 42901
# | Total Page/Swap (MB): 0 | Free Page/Swap: 0
# |---------------------------------------------------------------------------------------------|
# 2026-05-08 05:11:15 [2,876ms] [Warning] [gpu.foundation.plugin] ECC is enabled for device 0. This will reduce rendering performance.
# 2026-05-08 05:11:15 [2,876ms] [Warning] [gpu.foundation.plugin]
# 2026-05-08 05:11:15 [2,876ms] [Warning] [gpu.foundation.plugin] -----------------------------------------------------------------------
# 2026-05-08 05:11:15 [2,876ms] [Warning] [gpu.foundation.plugin] !!!!! Local system validation failed! Incorrect configuration detected.
# 2026-05-08 05:11:15 [2,876ms] [Warning] [gpu.foundation.plugin]       Summary below. Details above.
# 2026-05-08 05:11:15 [2,876ms] [Warning] [gpu.foundation.plugin] -----------------------------------------------------------------------
# 2026-05-08 05:11:15 [2,876ms] [Warning] [gpu.foundation.plugin]
# 2026-05-08 05:11:15 [2,876ms] [Warning] [gpu.foundation.plugin]  - ECC:                         FAILED
# 2026-05-08 05:11:15 [2,877ms] [Warning] [gpu.foundation.plugin]  - IOMMU:                       OK
# 2026-05-08 05:11:15 [2,877ms] [Warning] [gpu.foundation.plugin]
# 2026-05-08 05:11:15 [2,877ms] [Warning] [gpu.foundation.plugin] -----------------------------------------------------------------------
# [3.196s] [ext: omni.kit.pipapi-0.0.0] startup
# [3.275s] [ext: omni.kit.pip_archive-0.0.0] startup
# [3.325s] [ext: omni.kit.loop-isaac-1.0.0] startup
# [3.333s] [ext: omni.kit.async_engine-0.0.0] startup
# [3.340s] [ext: omni.kit.test-0.0.0] startup
# [3.746s] [ext: omni.usd.config-1.0.0] startup
# [3.764s] [ext: omni.usd.libs-1.0.0] startup
# [4.512s] [ext: omni.isaac.core_archive-2.0.1] startup
# [5.089s] [ext: omni.pip.torch-1_13_1-0.1.4] startup
# [5.101s] [ext: omni.isaac.ml_archive-1.1.0] startup
# [5.359s] [ext: omni.client-0.1.1] startup
# [5.449s] [ext: omni.appwindow-1.0.1] startup
# 2026-05-08 05:11:18 [5,390ms] [Warning] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2026-05-08 05:11:18 [5,390ms] [Warning] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.3]) (impl: carb.windowing-glfw.plugin)
# [5.462s] [ext: omni.kit.renderer.core-0.0.0] startup
# 2026-05-08 05:11:18 [5,407ms] [Warning] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2026-05-08 05:11:18 [5,407ms] [Warning] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.3]) (impl: carb.windowing-glfw.plugin)
# 2026-05-08 05:11:18 [5,409ms] [Warning] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2026-05-08 05:11:18 [5,409ms] [Warning] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.3]) (impl: carb.windowing-glfw.plugin)
# [5.489s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [5.508s] [ext: omni.kit.renderer.imgui-0.0.0] startup
# 2026-05-08 05:11:18 [5,470ms] [Warning] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2026-05-08 05:11:18 [5,470ms] [Warning] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.3]) (impl: carb.windowing-glfw.plugin)
# 2026-05-08 05:11:18 [5,471ms] [Warning] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2026-05-08 05:11:18 [5,471ms] [Warning] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.3]) (impl: carb.windowing-glfw.plugin)
# [5.651s] [ext: carb.audio-0.1.0] startup
# [5.665s] [ext: omni.ui-2.14.4] startup
# [5.723s] [ext: omni.uiaudio-1.0.0] startup
# [5.734s] [ext: omni.kit.mainwindow-1.0.0] startup
# [5.746s] [ext: omni.kit.uiapp-0.0.0] startup
# [5.746s] [ext: omni.usd.schema.physics-1.0.0] startup
# [5.875s] [ext: omni.usd.schema.isaac-1.1.0] startup
# [5.936s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [5.977s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [6.008s] [ext: omni.usd.schema.forcefield-0.0.0] startup
# [6.037s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [6.063s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [6.089s] [ext: omni.usd.schema.anim-0.0.0] startup
# [6.247s] [ext: omni.usd.schema.audio-0.0.0] startup
# [6.269s] [ext: omni.usd.schema.scene.visualization-1.0.0] startup
# [6.281s] [ext: omni.usd.schema.physx-0.0.0] startup
# [6.373s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [6.379s] [ext: omni.timeline-1.0.5] startup
# [6.389s] [ext: omni.kit.search_core-1.0.2] startup
# [6.399s] [ext: omni.hydra.scene_delegate-0.3.0] startup
# [6.423s] [ext: omni.kit.widget.path_field-2.0.4] startup
# [6.454s] [ext: omni.kit.widget.filebrowser-2.3.10] startup
# [6.566s] [ext: omni.kit.widget.browser_bar-2.0.5] startup
# [6.576s] [ext: omni.kit.window.popup_dialog-2.0.16] startup
# [6.604s] [ext: omni.kit.actions.core-1.0.0] startup
# [6.621s] [ext: omni.usd.core-1.0.4] startup
# [6.624s] [ext: omni.kit.audiodeviceenum-1.0.0] startup
# [6.633s] [ext: omni.kit.widget.nucleus_connector-1.0.3] startup
# [6.648s] [ext: omni.kit.commands-1.4.5] startup
# [6.681s] [ext: omni.hydra.usdrt_delegate-4.3.2] startup
# [6.717s] [ext: omni.kit.notification_manager-1.0.5] startup
# [6.743s] [ext: omni.usd-1.6.30] startup
# [6.945s] [ext: omni.kit.widget.versioning-1.3.8] startup
# [6.969s] [ext: omni.iray.libs-0.0.0] startup
# [7.153s] [ext: omni.kit.window.filepicker-2.7.15] startup
# [7.355s] [ext: omni.mdl.neuraylib-0.1.0] startup
# [7.373s] [ext: omni.kit.collaboration.channel_manager-1.0.9] startup
# [7.388s] [ext: omni.kit.window.file_importer-1.0.10] startup
# [7.400s] [ext: omni.mdl-0.1.0] startup
# [7.630s] [ext: omni.kit.usd.layers-2.0.11] startup
# [7.687s] [ext: omni.kit.menu.utils-1.4.7] startup
# [7.752s] [ext: omni.kit.material.library-1.3.21] startup
# [7.782s] [ext: omni.kit.menu.create-1.0.8] startup
# [7.797s] [ext: omni.kit.clipboard-1.0.0] startup
# [7.803s] [ext: omni.kit.widget.graph-1.5.6-104_2] startup
# [8.067s] [ext: omni.kit.context_menu-1.5.12] startup
# [8.100s] [ext: omni.kit.window.extensions-1.1.1] startup
# [8.157s] [ext: omni.inspect-1.0.1] startup
# [8.176s] [ext: omni.kit.window.property-1.8.2] startup
# [8.193s] [ext: omni.kit.primitive.mesh-1.0.8] startup
# [8.228s] [ext: omni.graph.core-2.65.4] startup
# [8.249s] [ext: omni.isaac.version-1.0.0] startup
# [8.256s] [ext: omni.kit.stage_templates-1.1.13] startup
# [8.273s] [ext: omni.kit.usd_undo-0.1.2] startup
# [8.280s] [ext: omni.graph.tools-1.17.2] startup
# [8.422s] [ext: omni.ui.scene-1.5.18] startup
# [8.446s] [ext: omni.graph-1.50.2] startup
# [8.704s] [ext: omni.ui_query-1.1.1] startup
# [8.713s] [ext: omni.volume-0.1.0] startup
# [8.735s] [ext: omni.kit.ui_test-1.2.9] startup
# [8.750s] [ext: omni.hydra.rtx-0.1.0] startup
# [8.826s] [ext: omni.kit.widget.searchfield-1.0.10] startup
# [8.842s] [ext: omni.kit.graph.delegate.default-1.0.18] startup
# [8.854s] [ext: omni.debugdraw-0.1.1] startup
# [8.873s] [ext: omni.kit.graph.editor.core-1.4.7] startup
# [8.901s] [ext: omni.hydra.pxr-1.1.2] startup
# [8.921s] [ext: omni.activity.core-1.0.1] startup
# [8.936s] [ext: omni.kit.hydra_texture-1.0.11] startup
# [8.958s] [ext: omni.kit.viewport.legacy_gizmos-1.0.10] startup
# [8.980s] [ext: omni.kit.viewport.registry-104.0.2] startup
# [8.988s] [ext: omni.kit.widget.viewport-104.1.16] startup
# [9.023s] [ext: omni.kit.window.drop_support-1.0.1] startup
# [9.032s] [ext: omni.kit.window.file_exporter-1.0.10] startup
# [9.043s] [ext: omni.hydra.engine.stats-1.0.0] startup
# [9.056s] [ext: omni.kit.window.content_browser_registry-0.0.1] startup
# [9.065s] [ext: omni.kit.window.file-1.3.32] startup
# [9.093s] [ext: omni.kit.viewport.window-104.1.23] startup
# [9.238s] [ext: omni.kit.widget.settings-1.0.1] startup
# [9.256s] [ext: omni.kit.widget.stage-2.7.24] startup
# [9.302s] [ext: omni.kit.window.content_browser-2.6.8] startup
# [9.397s] [ext: omni.kit.viewport.utility-1.0.14] startup
# [9.411s] [ext: omni.kit.window.preferences-1.3.8] startup
# [9.507s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [9.521s] [ext: omni.kit.widget.prompt-1.0.5] startup
# [9.533s] [ext: omni.kit.property.usd-3.18.17] startup
# [9.622s] [ext: omni.kit.graph.delegate.modern-1.6.5] startup
# [9.644s] [ext: omni.graph.ui-1.24.2] startup
# [9.904s] [ext: omni.physics.tensors-0.1.0] startup
# [9.939s] [ext: omni.kit.graph.widget.variables-2.0.4] startup
# [9.955s] [ext: omni.kit.graph.usd.commands-1.2.0] startup
# [9.966s] [ext: omni.convexdecomposition-104.2.4-5.1] startup
# [9.981s] [ext: omni.graph.window.core-1.43.3] startup
# [10.064s] [ext: omni.kit.widget.zoombar-1.0.4] startup
# [10.076s] [ext: omni.kvdb-0.0.0] startup
# [10.092s] [ext: omni.usdphysics-104.2.4-5.1] startup
# [10.098s] [ext: omni.localcache-0.0.0] startup
# [10.111s] [ext: omni.graph.scriptnode-0.10.0] startup
# [10.131s] [ext: omni.physx-104.2.4-5.1] startup
# [10.217s] [ext: omni.command.usd-1.0.2] startup
# [10.229s] [ext: omni.physx.tensors-0.1.0] startup
# [10.252s] [ext: omni.graph.window.generic-1.3.15] startup
# [10.266s] [ext: omni.kit.browser.core-2.2.2] startup
# [10.308s] [ext: omni.graph.action-1.31.1] startup
# [10.421s] [ext: omni.kit.browser.folder.core-1.7.3] startup
# [10.460s] [ext: omni.kit.window.cursor-1.1.1] startup
# [10.468s] [ext: omni.kit.widget.spinner-1.0.4] startup
# [10.480s] [ext: omni.kit.browser.sample-1.2.5] startup
# [10.492s] [ext: omni.graph.nodes-1.48.3] startup
# [10.592s] [ext: omni.kit.viewport.menubar.core-104.4.3] startup
# [10.713s] [ext: omni.kit.numpy.common-0.1.0] startup
# [10.727s] [ext: omni.warp-0.6.3] startup
# Warp 0.6.3 initialized:
#    CUDA Toolkit: 11.5, Driver: 13.1
#    Devices:
#      "cpu"    | x86_64
#      "cuda:0" | NVIDIA L4 (sm_89)
#    Kernel cache: /root/.cache/warp/0.6.3
# WARNING: Attribute 'inputs:execIn' description should not be empty
# WARNING: Attribute 'inputs:sdf_min' description should not be empty
# WARNING: Attribute 'inputs:sdf_max' description should not be empty
# WARNING: Attribute 'inputs:spacing' description should not be empty
# WARNING: Attribute 'inputs:spacing_jitter' description should not be empty
# WARNING: Attribute 'inputs:velocity' description should not be empty
# WARNING: Attribute 'inputs:max_points' description should not be empty
# WARNING: Attribute 'inputs:mass' description should not be empty
# WARNING: Attribute 'inputs:radius' description should not be empty
# WARNING: Attribute 'inputs:k_contact_elastic' description should not be empty
# WARNING: Attribute 'inputs:k_contact_damp' description should not be empty
# WARNING: Attribute 'inputs:k_contact_friction' description should not be empty
# WARNING: Attribute 'inputs:k_contact_mu' description should not be empty
# WARNING: Attribute 'inputs:k_contact_cohesion' description should not be empty
# WARNING: Attribute 'inputs:k_contact_adhesion' description should not be empty
# WARNING: Attribute 'inputs:num_substeps' description should not be empty
# WARNING: Attribute 'inputs:gravity' description should not be empty
# WARNING: Attribute 'inputs:ground' description should not be empty
# WARNING: Attribute 'inputs:ground_plane' description should not be empty
# WARNING: Attribute 'inputs:asynchronous' description should not be empty
# WARNING: Attribute 'inputs:collider_offset' description should not be empty
# WARNING: Attribute 'inputs:ground' description should not be empty
# WARNING: Attribute 'inputs:ground_plane' description should not be empty
# WARNING: Attribute 'inputs:density' description should not be empty
# WARNING: Attribute 'inputs:k_tri_elastic' description should not be empty
# WARNING: Attribute 'inputs:k_tri_area' description should not be empty
# WARNING: Attribute 'inputs:k_tri_damp' description should not be empty
# WARNING: Attribute 'inputs:k_edge_bend' description should not be empty
# WARNING: Attribute 'inputs:k_edge_damp' description should not be empty
# WARNING: Attribute 'inputs:k_contact_elastic' description should not be empty
# WARNING: Attribute 'inputs:k_contact_damp' description should not be empty
# WARNING: Attribute 'inputs:k_contact_friction' description should not be empty
# WARNING: Attribute 'inputs:k_contact_mu' description should not be empty
# WARNING: Attribute 'inputs:num_substeps' description should not be empty
# WARNING: Attribute 'inputs:gravity' description should not be empty
# WARNING: Attribute 'inputs:resolution' description should not be empty
# WARNING: Attribute 'inputs:speed' description should not be empty
# WARNING: Attribute 'inputs:damp' description should not be empty
# WARNING: Attribute 'inputs:grid' description should not be empty
# WARNING: Attribute 'inputs:collider_0' description should not be empty
# WARNING: Attribute 'inputs:collider_1' description should not be empty
# WARNING: Attribute 'inputs:collider_2' description should not be empty
# WARNING: Attribute 'inputs:collider_3' description should not be empty
# WARNING: Attribute 'inputs:buoyancy_enabled' description should not be empty
# WARNING: Attribute 'inputs:density_0' description should not be empty
# WARNING: Attribute 'inputs:density_1' description should not be empty
# WARNING: Attribute 'inputs:density_2' description should not be empty
# WARNING: Attribute 'inputs:density_3' description should not be empty
# WARNING: Attribute 'inputs:displace' description should not be empty
# WARNING: Attribute 'inputs:gravity' description should not be empty
# WARNING: Attribute 'inputs:buoyancy' description should not be empty
# WARNING: Attribute 'inputs:buoyancy_damp' description should not be empty
# WARNING: Attribute 'inputs:delay' description should not be empty
# WARNING: Attribute 'outputs:vertices' description should not be empty
# WARNING: Attribute 'outputs:face_indices' description should not be empty
# WARNING: Attribute 'outputs:face_counts' description should not be empty
# WARNING: Attribute 'inputs:fps' description should not be empty
# WARNING: Attribute 'inputs:start' description should not be empty
# WARNING: Attribute 'inputs:end' description should not be empty
# WARNING: Attribute 'outputs:time' description should not be empty
# WARNING: Node description should not be empty
# [11.355s] [ext: omni.syntheticdata-0.2.4] startup
# 2026-05-08 05:11:24 [11,383ms] [Warning] [omni.kit.viewport.menubar.core.menu_item.viewport_menu_item] ViewportMenuItem order argument is deprecated, use order_setting_path
# [11.465s] [ext: omni.isaac.dynamic_control-1.2.3] startup
# [11.532s] [ext: omni.replicator.core-1.7.8] startup
# 2026-05-08 05:11:24 [12,157ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# [12.929s] [ext: omni.isaac.core-1.46.3] startup
# [16.798s] [ext: omni.kit.manipulator.viewport-104.0.7] startup
# [16.811s] [ext: omni.isaac.core_nodes-0.23.2] startup
# [16.910s] [ext: omni.isaac.cloner-0.4.1] startup
# [16.923s] [ext: omni.isaac.lula-1.2.1] startup
# [16.995s] [ext: omni.graph.visualization.nodes-2.0.0] startup
# [17.036s] [ext: omni.isaac.debug_draw-0.2.3] startup
# [17.062s] [ext: omni.isaac.gym-0.3.3] startup
# [17.070s] [ext: omni.graph.window.action-1.5.5] startup
# [17.085s] [ext: omni.isaac.ui-0.8.0] startup
# [17.131s] [ext: usdrt.scenegraph-4.3.2] startup
# [17.218s] [ext: omni.isaac.motion_planning-0.2.2] startup
# [17.282s] [ext: omni.isaac.surface_gripper-0.4.0] startup
# [17.330s] [ext: omni.isaac.range_sensor-0.8.1] startup
# [17.520s] [ext: omni.isaac.motion_generation-4.5.6] startup
# [17.602s] [ext: omni.isaac.manipulators-1.1.0] startup
# [17.623s] [ext: omni.isaac.sensor-5.6.3] startup
# 2026-05-08 05:11:30 [17,562ms] [Warning] [omni.ext.plugin] [ext: omni.isaac.sensor-5.6.3] Native plugin search dir contains several files: /isaac-sim/exts/omni.isaac.sensor/bin . It makes dir walk slow, replace with the exact path to the plugin instead of a wildcard.
# [17.932s] [ext: omni.isaac.dofbot-0.3.0] startup
# [17.943s] [ext: omni.isaac.occupancy_map-0.2.7] startup
# [17.989s] [ext: omni.isaac.quadruped-1.3.0] startup
# [19.894s] [ext: omni.isaac.scene_blox-0.1.0] startup
# [19.903s] [ext: omni.isaac.synthetic_utils-0.4.3] startup
# [19.932s] [ext: omni.isaac.universal_robots-0.3.2] startup
# [19.943s] [ext: omni.isaac.isaac_sensor-2.0.0] startup
# 2026-05-08 05:11:32 [19,889ms] [Warning] [omni.isaac.isaac_sensor] omni.isaac.isaac_sensor is deprecated and was renamed; use omni.isaac.sensor
# [19.952s] [ext: omni.kit.widget.live_session_management-1.1.3] startup
# [19.981s] [ext: omni.kit.hotkeys.core-1.0.8] startup
# [20.039s] [ext: omni.isaac.wheeled_robots-0.6.3] startup
# [20.138s] [ext: omni.kit.widget.stage_icons-1.0.2] startup
# [20.154s] [ext: omni.kit.widget.layers-1.6.11] startup
# [20.248s] [ext: omni.kit.selection-0.1.0] startup
# [20.261s] [ext: omni.isaac.mjcf-0.3.1] startup
# [20.316s] [ext: omni.kit.window.stage-2.3.12] startup
# [20.337s] [ext: omni.kit.property.layer-1.1.4] startup
# [20.358s] [ext: omni.kit.menu.edit-1.1.6] startup
# [20.381s] [ext: omni.kit.menu.file-1.1.4] startup
# [20.400s] [ext: omni.kit.menu.stage-1.2.1] startup
# [20.413s] [ext: omni.kit.property.audio-1.0.6] startup
# [20.434s] [ext: omni.kit.property.camera-1.0.3] startup
# [20.451s] [ext: omni.kit.property.geometry-1.2.2] startup
# [20.474s] [ext: omni.kit.property.light-1.0.6] startup
# [20.491s] [ext: omni.hydra.scene_api-0.1.1] startup
# [20.512s] [ext: omni.kit.property.material-1.8.19] startup
# [20.543s] [ext: omni.kit.property.render-1.1.0] startup
# [20.556s] [ext: omni.kit.property.skel-1.0.1] startup
# [20.573s] [ext: omni.kit.property.transform-1.3.5] startup
# [20.617s] [ext: omni.kit.manipulator.transform-104.6.12] startup
# [20.633s] [ext: omni.kit.widget.toolbar-1.4.0] startup
# [20.678s] [ext: omni.kit.profiler.window-2.0.5] startup
# [21.069s] [ext: omni.kit.property.bundle-1.2.6] startup
# [21.085s] [ext: omni.kit.manipulator.selector-1.0.1] startup
# [21.101s] [ext: omni.kit.manipulator.tool.snap-1.2.4] startup
# [21.158s] [ext: omni.kit.window.toolbar-1.4.0] startup
# [21.175s] [ext: omni.kit.property.isaac-0.2.0] startup
# [21.192s] [ext: omni.kit.stage_column.payload-1.0.8] startup
# [21.209s] [ext: omni.kit.manipulator.camera-104.0.23] startup
# [21.210s] [ext: omni.kit.manipulator.prim-104.10.7] startup
# [21.259s] [ext: omni.kit.manipulator.selection-104.0.6] startup
# [21.259s] [ext: omni.kit.viewport.menubar.display-104.1.11] startup
# [21.280s] [ext: omni.kit.viewport.menubar.camera-104.1.9] startup
# [21.323s] [ext: omni.rtx.window.settings-0.6.2] startup
# [21.356s] [ext: omni.kit.viewport.menubar.settings-104.3.5] startup
# [21.403s] [ext: omni.kit.viewport.menubar.render-104.0.20] startup
# [21.429s] [ext: omni.physx.commands-104.2.4-5.1] startup
# [21.465s] [ext: omni.kit.stage_column.variant-1.0.9] startup
# [21.481s] [ext: omni.hydra.pxr.settings-1.0.3] startup
# [21.497s] [ext: omni.kit.viewport.bundle-104.0.2] startup
# [21.497s] [ext: omni.physx.ui-104.2.4-5.1] startup
# [21.652s] [ext: omni.kit.viewport.menubar.lighting-104.0.9] startup
# [21.678s] [ext: omni.kit.viewport.pxr-104.0.1] startup
# [21.678s] [ext: omni.kit.viewport.ready-1.0.2] startup
# [21.689s] [ext: omni.physx.demos-104.2.4-5.1] startup
# [21.709s] [ext: omni.kit.property.physx-0.1.0] startup
# [21.841s] [ext: omni.isaac.urdf-0.5.9] startup
# [21.929s] [ext: omni.kit.widget.highlight_label-1.0.0] startup
# [21.942s] [ext: omni.physx.supportui-104.2.4-5.1] startup
# [22.012s] [ext: omni.physx.vehicle-104.2.4-5.1] startup
# [22.095s] [ext: omni.physx.cct-104.2.4-5.1] startup
# [22.127s] [ext: omni.physx.camera-104.2.4-5.1] startup
# [22.354s] [ext: omni.kit.actions.window-1.1.0] startup
# [22.404s] [ext: omni.kit.window.commands-0.2.4] startup
# [22.422s] [ext: omni.kit.window.console-0.2.3] startup
# [22.455s] [ext: omni.physx.bundle-104.2.4-5.1] startup
# [22.455s] [ext: omni.graph.bundle.action-1.3.0] startup
# [22.455s] [ext: omni.kit.window.script_editor-1.7.2] startup
# [22.481s] [ext: omni.kit.hotkeys.window-1.1.3] startup
# [22.536s] [ext: omni.kit.window.status_bar-0.1.5] startup
# [22.556s] [ext: omni.kit.window.title-1.1.2] startup
# 2026-05-08 05:11:35 [22,505ms] [Warning] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2026-05-08 05:11:35 [22,505ms] [Warning] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.3]) (impl: carb.windowing-glfw.plugin)
# 2026-05-08 05:11:35 [22,507ms] [Warning] [carb] [Plugin: libomni.structuredlog.plugin.so] Module /isaac-sim/kit/libomni.structuredlog.plugin.so remained loaded after unload request
# 2026-05-08 05:11:35 [22,508ms] [Warning] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2026-05-08 05:11:35 [22,508ms] [Warning] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.3]) (impl: carb.windowing-glfw.plugin)
# [22.574s] [ext: omni.replicator.composer-1.2.10] startup
# [22.623s] [ext: omni.replicator.isaac-1.7.4] startup
# [22.771s] [ext: omni.resourcemonitor-1.0.0] startup
# [22.800s] [ext: omni.rtx.settings.core-0.5.8] startup
# [22.834s] [ext: omni.isaac.franka-0.4.0] startup
# [22.845s] [ext: omni.kit.viewport.rtx-104.0.0] startup
# [22.845s] [ext: semantics.schema.editor-0.3.3] startup
# [22.866s] [ext: omni.kit.widget.live-2.0.3] startup
# 2026-05-08 05:11:35 [22,822ms] [Warning] [omni.kit.widget.live.cache_state_menu] Unable to detect Omniverse Cache Server. Consider installing it for better IO performance.
# [22.885s] [ext: omni.isaac.utils-0.2.4] startup
# [22.910s] [ext: omni.isaac.kit-1.4.1] startup
# [22.910s] [ext: omni.isaac.cortex-0.3.2] startup
# [22.919s] [ext: omni.kit.window.stats-0.1.2] startup
# [22.932s] [ext: omni.isaac.sim.python-2022.2.1] startup
# [22.935s] Simulation App Starting
# 2026-05-08 05:11:36 [23,422ms] [Warning] [rtx.neuraylib.plugin] [IRAY:RENDER]   1.1   IRAY   rend warn : CUDA device 0 (NVIDIA L4): ECC is enabled, this will reduce rendering performance (it is strongly recommended to disable ECC with iray)
# [23.714s] [ext: omni.isaac.sim.python-2022.2.1] shutdown
# [23.714s] [ext: omni.isaac.universal_robots-0.3.2] shutdown
# [23.917s] [ext: omni.isaac.cortex-0.3.2] shutdown
# [24.120s] [ext: omni.isaac.franka-0.4.0] shutdown
# [24.319s] [ext: omni.isaac.dofbot-0.3.0] shutdown
# [24.518s] [ext: omni.isaac.manipulators-1.1.0] shutdown
# [24.724s] [ext: omni.isaac.surface_gripper-0.4.0] shutdown
# 2026-05-08 05:11:37 [24,902ms] [Warning] [omni.ext._impl._internal] omni.isaac.surface_gripper-0.4.0 -> <class 'omni.isaac.surface_gripper.scripts.extension.Extension'>: extension object is still alive, something holds a reference on it. References: ["[0]:type: <class 'method'>, id: 136201288810320"]
# [25.164s] [ext: omni.isaac.wheeled_robots-0.6.3] shutdown
# [25.378s] [ext: omni.isaac.surface_gripper-0.4.0] startup
# [25.393s] [ext: omni.isaac.manipulators-1.1.0] startup
# [25.395s] [ext: omni.isaac.dofbot-0.3.0] startup
# [25.396s] [ext: omni.isaac.universal_robots-0.3.2] startup
# [25.399s] [ext: omni.isaac.wheeled_robots-0.6.3] startup
# [25.409s] [ext: omni.isaac.franka-0.4.0] startup
# [25.411s] [ext: omni.isaac.cortex-0.3.2] startup
# [25.412s] [ext: omni.isaac.sim.python-2022.2.1] startup
# 2026-05-08 05:12:13 [61,054ms] [Warning] [gpu.foundation.plugin] Waiting for compilation of ray tracing shaders by GPU driver: 30 seconds so far
# 2026-05-08 05:12:43 [91,057ms] [Warning] [gpu.foundation.plugin] Waiting for compilation of ray tracing shaders by GPU driver: 60 seconds so far
# 2026-05-08 05:13:13 [121,057ms] [Warning] [gpu.foundation.plugin] Waiting for compilation of ray tracing shaders by GPU driver: 90 seconds so far
# 2026-05-08 05:13:43 [151,058ms] [Warning] [gpu.foundation.plugin] Waiting for compilation of ray tracing shaders by GPU driver: 120 seconds so far
# 2026-05-08 05:14:13 [181,058ms] [Warning] [gpu.foundation.plugin] Waiting for compilation of ray tracing shaders by GPU driver: 150 seconds so far
# 2026-05-08 05:14:43 [211,058ms] [Warning] [gpu.foundation.plugin] Waiting for compilation of ray tracing shaders by GPU driver: 180 seconds so far
# 2026-05-08 05:15:13 [241,058ms] [Warning] [gpu.foundation.plugin] Waiting for compilation of ray tracing shaders by GPU driver: 210 seconds so far
# 2026-05-08 05:15:43 [271,059ms] [Warning] [gpu.foundation.plugin] Waiting for compilation of ray tracing shaders by GPU driver: 240 seconds so far
# 2026-05-08 05:16:13 [301,059ms] [Warning] [gpu.foundation.plugin] Waiting for compilation of ray tracing shaders by GPU driver: 270 seconds so far
# 2026-05-08 05:16:40 [327,351ms] [Warning] [gpu.foundation.plugin] Ray tracing shader compilation finished after 296 seconds
# [327.778s] app ready
# [328.393s] RTX ready
# [328.619s] Simulation App Startup Complete
# Loading Stage /Isaac/Environments/Simple_Warehouse/warehouse.usd
# 2026-05-08 05:16:41 [328,595ms] [Warning] [omni.client.plugin]  Tick: authentication: Discovery(ws://localhost/omni/discovery): Error creating Auth/Credentials search: Not connected
# 2026-05-08 05:16:41 [328,595ms] [Warning] [omni.client.plugin]  Tick: authentication: Discovery(ws://localhost/omni/discovery): Error creating Auth/Tokens search: Not connected
# 2026-05-08 05:16:41 [328,595ms] [Warning] [omni.client.plugin]  Tick: authentication: Discovery(ws://localhost/omni/discovery): Error creating Api/Connection search: Not connected
# 2026-05-08 05:16:41 [328,638ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# App uppdate 0..
# 2026-05-08 05:16:49 [336,396ms] [Warning] [omni.physx.plugin] PhysX warning: TriangleMesh: triangles are too big, reduce their size to increase simulation stability!, FILE /buildAgent/work/16dcef52b68a730f/source/geomutils/src/cooking/GuCookingTriangleMesh.cpp, LINE 202
# 2026-05-08 05:16:49 [336,396ms] [Warning] [omni.physx.plugin] PhysX warning: TriangleMesh: triangles are too big, reduce their size to increase simulation stability!, FILE /buildAgent/work/16dcef52b68a730f/source/geomutils/src/cooking/GuCookingTriangleMesh.cpp, LINE 202
# 2026-05-08 05:16:49 [336,396ms] [Warning] [omni.physx.plugin] PhysX warning: TriangleMesh: triangles are too big, reduce their size to increase simulation stability!, FILE /buildAgent/work/16dcef52b68a730f/source/geomutils/src/cooking/GuCookingTriangleMesh.cpp, LINE 202
# 2026-05-08 05:16:49 [336,396ms] [Warning] [omni.physx.plugin] PhysX warning: TriangleMesh: triangles are too big, reduce their size to increase simulation stability!, FILE /buildAgent/work/16dcef52b68a730f/source/geomutils/src/cooking/GuCookingTriangleMesh.cpp, LINE 202
# 2026-05-08 05:16:54 [341,768ms] [Warning] [omni.hydra.scene_delegate.plugin] Calling getBypassRenderSkelMeshProcessing for prim /Root/PaintTool/rock_small_06_93e2d/pointInstancer.proto0_rock_id0 that has not been populated
# 2026-05-08 05:17:49 [396,398ms] [Warning] [gpu.foundation.plugin] Waiting for compilation of ray tracing shaders by GPU driver: 30 seconds so far
# 2026-05-08 05:17:52 [399,516ms] [Warning] [gpu.foundation.plugin] Ray tracing shader compilation finished after 33 seconds
# 2026-05-08 05:17:52 [399,579ms] [Warning] [omni.physx.plugin] PhysX warning: TriangleMesh: triangles are too big, reduce their size to increase simulation stability!, FILE /buildAgent/work/16dcef52b68a730f/source/geomutils/src/cooking/GuCookingTriangleMesh.cpp, LINE 202
# 2026-05-08 05:17:52 [399,579ms] [Warning] [omni.physx.plugin] PhysX warning: TriangleMesh: triangles are too big, reduce their size to increase simulation stability!, FILE /buildAgent/work/16dcef52b68a730f/source/geomutils/src/cooking/GuCookingTriangleMesh.cpp, LINE 202
# 2026-05-08 05:18:53 [460,795ms] [Warning] [omni.physx.plugin] PhysX warning: TriangleMesh: triangles are too big, reduce their size to increase simulation stability!, FILE /buildAgent/work/16dcef52b68a730f/source/geomutils/src/cooking/GuCookingTriangleMesh.cpp, LINE 202
# App uppdate 10..
# App uppdate 20..
# App uppdate 30..
# App uppdate 40..
# App uppdate 50..
# App uppdate 60..
# App uppdate 70..
# App uppdate 80..
# App uppdate 90..
# 2026-05-08 05:18:55 [462,825ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,825ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,826ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,827ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,828ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,828ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,829ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,830ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,830ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,831ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,831ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,832ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,832ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,833ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,833ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,834ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,834ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,835ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,835ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,836ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,836ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,837ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,838ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,838ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,839ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,839ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,840ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,841ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,842ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,843ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [462,843ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:55 [463,185ms] [Warning] [carb.flatcache.plugin] UsdRelationship /Replicator/SDGPipeline/OgnGroup.inputs:prims has multiple targets, which is not supported
#
# 2026-05-08 05:18:56 [463,909ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,910ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,911ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,911ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,912ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,912ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,913ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,913ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,914ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,915ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,916ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,916ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,917ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,918ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,919ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,919ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,920ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,921ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,922ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,922ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,923ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,924ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,924ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,925ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,926ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,927ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,927ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,928ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,929ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,929ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,930ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,931ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,931ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,932ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,933ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,933ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,934ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,935ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,936ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,937ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,938ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,939ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,940ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,941ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,941ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,942ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,943ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,944ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,944ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,945ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,946ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,946ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,947ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,947ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,948ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,948ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,948ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,949ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,949ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,950ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,950ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 05:18:56 [463,951ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# Outputting data to  /isaac-sim/palletjack_sdg/palletjack_data/distractors_warehouse
# 2026-05-08 05:19:05 [473,147ms] [Warning] [rtx.neuraylib.plugin] [MDLC:COMPILER]   1.0   MDLC   comp warn : http://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/2022.2.1/Isaac/Environments/Simple_Warehouse/Materials/MaterialInstanceDynamic_1220.mdl?watch=00007bd1e1247c90(36,21): C183 unused parameter 'MultiMap_Box'
# 2026-05-08 05:19:05 [473,148ms] [Warning] [rtx.neuraylib.plugin] [MDLC:COMPILER]   1.0   MDLC   comp warn : http://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/2022.2.1/Isaac/Environments/Simple_Warehouse/Materials/MaterialInstanceDynamic_1220.mdl?watch=00007bd1e1247c90(36,21): C183 unused parameter 'MultiMap_Box'
# 2026-05-08 05:19:05 [473,149ms] [Warning] [rtx.neuraylib.plugin] [MDLC:COMPILER]   1.0   MDLC   comp warn : http://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/2022.2.1/Isaac/Environments/Simple_Warehouse/Materials/MaterialInstanceDynamic_1220.mdl?watch=00007bd1e1247c90(36,21): C183 unused parameter 'MultiMap_Box'
# 2026-05-08 05:19:05 [473,149ms] [Warning] [rtx.neuraylib.plugin] [MDLC:COMPILER]   1.0   MDLC   comp warn : http://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/2022.2.1/Isaac/Environments/Simple_Warehouse/Materials/MaterialInstanceDynamic_1220.mdl?watch=00007bd1e1247c90(36,21): C183 unused parameter 'MultiMap_Box'
# 2026-05-08 05:19:05 [473,149ms] [Warning] [rtx.neuraylib.plugin] Compiler Core: http://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/2022.2.1/Isaac/Environments/Simple_Warehouse/Materials/MaterialInstanceDynamic_1220.mdl?watch=00007bd1e1247c90(36,21): C183 unused parameter 'MultiMap_Box'
# 2026-05-08 05:19:05 [473,150ms] [Warning] [rtx.neuraylib.plugin] Compiler Core: http://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/2022.2.1/Isaac/Environments/Simple_Warehouse/Materials/MaterialInstanceDynamic_1220.mdl?watch=00007bd1e1247c90(36,21): C183 unused parameter 'MultiMap_Box'
# 2026-05-08 05:19:06 [473,704ms] [Warning] [carb.flatcache.plugin] PathToAttributesMap (0x31515300) contains attributes with duplicate name "camera" with different types but same per-element size. Data may become corrupted during request to move elements between buckets!
# 2026-05-08 05:19:07 [474,231ms] [Warning] [omni.hydra] Disabling DLSS Frame Generation for at least one view due to incompatible render outputs and OmniGraph postprocessing being active
# Module omni.replicator.core.ogn.python._impl.nodes.OgnSemanticSegmentation load on device 'cuda:0' took 602.11 ms
# 2026-05-08 05:20:40 [568,067ms] [Warning] [omni.replicator.core.scripts.writers] Writer version not specified in the writer metadata
# [1932.356s] Simulation App Shutting Down
# [Warning] [omni.isaac.kit.simulation_app] Modules: ['omni.isaac.kit.app_framework'] were loaded before SimulationApp was started and might not be loaded correctly.
# [Warning] [omni.isaac.kit.simulation_app] Please check to make sure no extra omniverse or pxr modules are imported before the call to SimulationApp(...)
# Starting kit application with the following args:  ['/isaac-sim/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/isaac-sim/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/isaac-sim/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=960', '--/app/renderer/resolution/height=544', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=True', '--ext-folder', '/isaac-sim/exts', '--ext-folder', '/isaac-sim/apps', '--/physics/cudaDevice=0', '--portable', '--no-window', '--allow-root']
# Passing the following args to the base kit application:  ['--headless', 'True', '--height', '544', '--width', '960', '--num_frames', '2000', '--distractors', 'additional', '--data_dir', '/isaac-sim/palletjack_sdg/palletjack_data/distractors_additional']
# ...
# [4.586s] [ext: omni.kit.window.file_exporter-1.0.10] startup
# [4.588s] [ext: omni.hydra.engine.stats-1.0.0] startup
# [4.594s] [ext: omni.kit.window.content_browser_registry-0.0.1] startup
# [4.595s] [ext: omni.kit.window.file-1.3.32] startup
# [4.599s] [ext: omni.kit.viewport.window-104.1.23] startup
# [4.644s] [ext: omni.kit.widget.settings-1.0.1] startup
# [4.647s] [ext: omni.kit.widget.stage-2.7.24] startup
# [4.653s] [ext: omni.kit.window.content_browser-2.6.8] startup
# [4.693s] [ext: omni.kit.viewport.utility-1.0.14] startup
# [4.694s] [ext: omni.kit.window.preferences-1.3.8] startup
# [4.816s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [4.819s] [ext: omni.kit.widget.prompt-1.0.5] startup
# [4.820s] [ext: omni.kit.property.usd-3.18.17] startup
# [4.836s] [ext: omni.kit.graph.delegate.modern-1.6.5] startup
# [4.838s] [ext: omni.graph.ui-1.24.2] startup
# [4.895s] [ext: omni.physics.tensors-0.1.0] startup
# [4.906s] [ext: omni.kit.graph.widget.variables-2.0.4] startup
# [4.908s] [ext: omni.kit.graph.usd.commands-1.2.0] startup
# [4.910s] [ext: omni.convexdecomposition-104.2.4-5.1] startup
# [4.913s] [ext: omni.graph.window.core-1.43.3] startup
# [4.927s] [ext: omni.kit.widget.zoombar-1.0.4] startup
# [4.928s] [ext: omni.kvdb-0.0.0] startup
# [4.932s] [ext: omni.usdphysics-104.2.4-5.1] startup
# [4.936s] [ext: omni.localcache-0.0.0] startup
# [4.939s] [ext: omni.graph.scriptnode-0.10.0] startup
# [4.944s] [ext: omni.physx-104.2.4-5.1] startup
# [4.972s] [ext: omni.command.usd-1.0.2] startup
# [4.977s] [ext: omni.physx.tensors-0.1.0] startup
# [4.988s] [ext: omni.graph.window.generic-1.3.15] startup
# [4.991s] [ext: omni.kit.browser.core-2.2.2] startup
# [5.000s] [ext: omni.graph.action-1.31.1] startup
# [5.012s] [ext: omni.kit.browser.folder.core-1.7.3] startup
# [5.018s] [ext: omni.kit.window.cursor-1.1.1] startup
# [5.019s] [ext: omni.kit.widget.spinner-1.0.4] startup
# [5.021s] [ext: omni.kit.browser.sample-1.2.5] startup
# [5.024s] [ext: omni.graph.nodes-1.48.3] startup
# [5.045s] [ext: omni.kit.viewport.menubar.core-104.4.3] startup
# [5.075s] [ext: omni.kit.numpy.common-0.1.0] startup
# [5.080s] [ext: omni.warp-0.6.3] startup
# Warp 0.6.3 initialized:
#    CUDA Toolkit: 11.5, Driver: 13.1
#    Devices:
#      "cpu"    | x86_64
#      "cuda:0" | NVIDIA L4 (sm_89)
#    Kernel cache: /root/.cache/warp/0.6.3
# [5.444s] [ext: omni.syntheticdata-0.2.4] startup
# 2026-05-08 06:09:27 [5,448ms] [Warning] [omni.kit.viewport.menubar.core.menu_item.viewport_menu_item] ViewportMenuItem order argument is deprecated, use order_setting_path
# [5.471s] [ext: omni.isaac.dynamic_control-1.2.3] startup
# [5.559s] [ext: omni.replicator.core-1.7.8] startup
# 2026-05-08 06:09:27 [5,679ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# [5.892s] [ext: omni.isaac.core-1.46.3] startup
# [7.116s] [ext: omni.kit.manipulator.viewport-104.0.7] startup
# [7.119s] [ext: omni.isaac.core_nodes-0.23.2] startup
# [7.142s] [ext: omni.isaac.cloner-0.4.1] startup
# [7.144s] [ext: omni.isaac.lula-1.2.1] startup
# [7.160s] [ext: omni.graph.visualization.nodes-2.0.0] startup
# [7.171s] [ext: omni.isaac.debug_draw-0.2.3] startup
# [7.183s] [ext: omni.isaac.gym-0.3.3] startup
# [7.185s] [ext: omni.graph.window.action-1.5.5] startup
# [7.189s] [ext: omni.isaac.ui-0.8.0] startup
# [7.197s] [ext: usdrt.scenegraph-4.3.2] startup
# [7.235s] [ext: omni.isaac.motion_planning-0.2.2] startup
# [7.253s] [ext: omni.isaac.surface_gripper-0.4.0] startup
# [7.261s] [ext: omni.isaac.range_sensor-0.8.1] startup
# [7.316s] [ext: omni.isaac.motion_generation-4.5.6] startup
# [7.326s] [ext: omni.isaac.manipulators-1.1.0] startup
# [7.329s] [ext: omni.isaac.sensor-5.6.3] startup
# 2026-05-08 06:09:29 [7,317ms] [Warning] [omni.ext.plugin] [ext: omni.isaac.sensor-5.6.3] Native plugin search dir contains several files: /isaac-sim/exts/omni.isaac.sensor/bin . It makes dir walk slow, replace with the exact path to the plugin instead of a wildcard.
# [7.509s] [ext: omni.isaac.dofbot-0.3.0] startup
# [7.511s] [ext: omni.isaac.occupancy_map-0.2.7] startup
# [7.528s] [ext: omni.isaac.quadruped-1.3.0] startup
# [7.912s] [ext: omni.isaac.scene_blox-0.1.0] startup
# [7.913s] [ext: omni.isaac.synthetic_utils-0.4.3] startup
# [7.916s] [ext: omni.isaac.universal_robots-0.3.2] startup
# [7.918s] [ext: omni.isaac.isaac_sensor-2.0.0] startup
# 2026-05-08 06:09:29 [7,905ms] [Warning] [omni.isaac.isaac_sensor] omni.isaac.isaac_sensor is deprecated and was renamed; use omni.isaac.sensor
# [7.919s] [ext: omni.kit.widget.live_session_management-1.1.3] startup
# [7.923s] [ext: omni.kit.hotkeys.core-1.0.8] startup
# [7.934s] [ext: omni.isaac.wheeled_robots-0.6.3] startup
# [7.947s] [ext: omni.kit.widget.stage_icons-1.0.2] startup
# [7.949s] [ext: omni.kit.widget.layers-1.6.11] startup
# [7.966s] [ext: omni.kit.selection-0.1.0] startup
# [7.969s] [ext: omni.isaac.mjcf-0.3.1] startup
# [7.981s] [ext: omni.kit.window.stage-2.3.12] startup
# [7.987s] [ext: omni.kit.property.layer-1.1.4] startup
# [7.994s] [ext: omni.kit.menu.edit-1.1.6] startup
# [7.999s] [ext: omni.kit.menu.file-1.1.4] startup
# [8.002s] [ext: omni.kit.menu.stage-1.2.1] startup
# [8.004s] [ext: omni.kit.property.audio-1.0.6] startup
# [8.006s] [ext: omni.kit.property.camera-1.0.3] startup
# [8.008s] [ext: omni.kit.property.geometry-1.2.2] startup
# [8.011s] [ext: omni.kit.property.light-1.0.6] startup
# [8.013s] [ext: omni.hydra.scene_api-0.1.1] startup
# [8.023s] [ext: omni.kit.property.material-1.8.19] startup
# [8.027s] [ext: omni.kit.property.render-1.1.0] startup
# [8.028s] [ext: omni.kit.property.skel-1.0.1] startup
# [8.031s] [ext: omni.kit.property.transform-1.3.5] startup
# [8.039s] [ext: omni.kit.manipulator.transform-104.6.12] startup
# [8.042s] [ext: omni.kit.widget.toolbar-1.4.0] startup
# [8.058s] [ext: omni.kit.profiler.window-2.0.5] startup
# [8.188s] [ext: omni.kit.property.bundle-1.2.6] startup
# [8.190s] [ext: omni.kit.manipulator.selector-1.0.1] startup
# [8.192s] [ext: omni.kit.manipulator.tool.snap-1.2.4] startup
# [8.203s] [ext: omni.kit.window.toolbar-1.4.0] startup
# [8.207s] [ext: omni.kit.property.isaac-0.2.0] startup
# [8.209s] [ext: omni.kit.stage_column.payload-1.0.8] startup
# [8.213s] [ext: omni.kit.manipulator.camera-104.0.23] startup
# [8.214s] [ext: omni.kit.manipulator.prim-104.10.7] startup
# [8.222s] [ext: omni.kit.manipulator.selection-104.0.6] startup
# [8.222s] [ext: omni.kit.viewport.menubar.display-104.1.11] startup
# [8.225s] [ext: omni.kit.viewport.menubar.camera-104.1.9] startup
# [8.232s] [ext: omni.rtx.window.settings-0.6.2] startup
# [8.240s] [ext: omni.kit.viewport.menubar.settings-104.3.5] startup
# [8.248s] [ext: omni.kit.viewport.menubar.render-104.0.20] startup
# [8.252s] [ext: omni.physx.commands-104.2.4-5.1] startup
# [8.260s] [ext: omni.kit.stage_column.variant-1.0.9] startup
# [8.262s] [ext: omni.hydra.pxr.settings-1.0.3] startup
# [8.264s] [ext: omni.kit.viewport.bundle-104.0.2] startup
# [8.264s] [ext: omni.physx.ui-104.2.4-5.1] startup
# [8.501s] [ext: omni.kit.viewport.menubar.lighting-104.0.9] startup
# [8.505s] [ext: omni.kit.viewport.pxr-104.0.1] startup
# [8.505s] [ext: omni.kit.viewport.ready-1.0.2] startup
# [8.507s] [ext: omni.physx.demos-104.2.4-5.1] startup
# [8.511s] [ext: omni.kit.property.physx-0.1.0] startup
# [8.591s] [ext: omni.isaac.urdf-0.5.9] startup
# [8.641s] [ext: omni.kit.widget.highlight_label-1.0.0] startup
# [8.643s] [ext: omni.physx.supportui-104.2.4-5.1] startup
# [8.665s] [ext: omni.physx.vehicle-104.2.4-5.1] startup
# [8.684s] [ext: omni.physx.cct-104.2.4-5.1] startup
# [8.696s] [ext: omni.physx.camera-104.2.4-5.1] startup
# [8.707s] [ext: omni.kit.actions.window-1.1.0] startup
# [8.715s] [ext: omni.kit.window.commands-0.2.4] startup
# [8.717s] [ext: omni.kit.window.console-0.2.3] startup
# [8.731s] [ext: omni.physx.bundle-104.2.4-5.1] startup
# [8.731s] [ext: omni.graph.bundle.action-1.3.0] startup
# [8.731s] [ext: omni.kit.window.script_editor-1.7.2] startup
# [8.735s] [ext: omni.kit.hotkeys.window-1.1.3] startup
# [8.745s] [ext: omni.kit.window.status_bar-0.1.5] startup
# [8.751s] [ext: omni.kit.window.title-1.1.2] startup
# 2026-05-08 06:09:30 [8,739ms] [Warning] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2026-05-08 06:09:30 [8,739ms] [Warning] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.3]) (impl: carb.windowing-glfw.plugin)
# 2026-05-08 06:09:30 [8,742ms] [Warning] [carb] [Plugin: libomni.structuredlog.plugin.so] Module /isaac-sim/kit/libomni.structuredlog.plugin.so remained loaded after unload request
# 2026-05-08 06:09:30 [8,743ms] [Warning] [carb.windowing-glfw.plugin] GLFW initialization failed.
# 2026-05-08 06:09:30 [8,743ms] [Warning] [carb] Failed to startup plugin carb.windowing-glfw.plugin (interfaces: [carb::windowing::IGLContext v1.0],[carb::windowing::IWindowing v1.3]) (impl: carb.windowing-glfw.plugin)
# [8.757s] [ext: omni.replicator.composer-1.2.10] startup
# [8.764s] [ext: omni.replicator.isaac-1.7.4] startup
# [8.788s] [ext: omni.resourcemonitor-1.0.0] startup
# [8.797s] [ext: omni.rtx.settings.core-0.5.8] startup
# [8.806s] [ext: omni.isaac.franka-0.4.0] startup
# [8.809s] [ext: omni.kit.viewport.rtx-104.0.0] startup
# [8.809s] [ext: semantics.schema.editor-0.3.3] startup
# [8.816s] [ext: omni.kit.widget.live-2.0.3] startup
# 2026-05-08 06:09:30 [8,805ms] [Warning] [omni.kit.widget.live.cache_state_menu] Unable to detect Omniverse Cache Server. Consider installing it for better IO performance.
# [8.819s] [ext: omni.isaac.utils-0.2.4] startup
# [8.825s] [ext: omni.isaac.kit-1.4.1] startup
# [8.825s] [ext: omni.isaac.cortex-0.3.2] startup
# [8.827s] [ext: omni.kit.window.stats-0.1.2] startup
# [8.829s] [ext: omni.isaac.sim.python-2022.2.1] startup
# [8.830s] Simulation App Starting
# 2026-05-08 06:09:30 [9,071ms] [Warning] [rtx.neuraylib.plugin] [IRAY:RENDER]   1.1   IRAY   rend warn : CUDA device 0 (NVIDIA L4): ECC is enabled, this will reduce rendering performance (it is strongly recommended to disable ECC with iray)
# 2026-05-08 06:10:04 [42,471ms] [Warning] [gpu.foundation.plugin] Waiting for compilation of ray tracing shaders by GPU driver: 30 seconds so far
# 2026-05-08 06:10:07 [46,051ms] [Warning] [gpu.foundation.plugin] Ray tracing shader compilation finished after 33 seconds
# [46.247s] app ready
# [46.577s] RTX ready
# [46.781s] Simulation App Startup Complete
# Loading Stage /Isaac/Environments/Simple_Warehouse/warehouse.usd
# 2026-05-08 06:10:08 [46,789ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# App uppdate 0..
# 2026-05-08 06:10:12 [50,469ms] [Warning] [omni.hydra.scene_delegate.plugin] Calling getBypassRenderSkelMeshProcessing for prim /Root/PaintTool/rock_small_13_a8039/pointInstancer.proto0_rock_id0 that has not been populated
# App uppdate 10..
# App uppdate 20..
# App uppdate 30..
# App uppdate 40..
# App uppdate 50..
# App uppdate 60..
# App uppdate 70..
# App uppdate 80..
# App uppdate 90..
# 2026-05-08 06:10:18 [56,775ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,776ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,776ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,777ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,777ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,778ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,779ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,779ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,780ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,780ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,781ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,782ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,782ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,783ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,783ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,784ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,784ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,785ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,786ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,786ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,787ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,787ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,788ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,788ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,789ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,789ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,790ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,790ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,791ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,791ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,792ms] [Warning] [omni.isaac.core.utils.nucleus] /persistent/app/omniverse/mountedDrives setting not found
# 2026-05-08 06:10:18 [56,868ms] [Warning] [carb.flatcache.plugin] UsdRelationship /Replicator/SDGPipeline/OgnGroup.inputs:prims has multiple targets, which is not supported
#
# No Distractors being added to the current scene for SDG
# Outputting data to  /isaac-sim/palletjack_sdg/palletjack_data/no_distractors
# 2026-05-08 06:10:21 [59,292ms] [Warning] [carb.flatcache.plugin] PathToAttributesMap (0x149b03c0) contains attributes with duplicate name "camera" with different types but same per-element size. Data may become corrupted during request to move elements between buckets!
# 2026-05-08 06:10:21 [59,710ms] [Warning] [omni.hydra] Disabling DLSS Frame Generation for at least one view due to incompatible render outputs and OmniGraph postprocessing being active
# Module omni.replicator.core.ogn.python._impl.nodes.OgnSemanticSegmentation load on device 'cuda:0' took 4.46 ms
# 2026-05-08 06:10:25 [63,944ms] [Warning] [omni.replicator.core.scripts.writers] Writer version not specified in the writer metadata
# [688.606s] Simulation App Shutting Down

# %% [markdown]
# The data generation will begin in `headless` mode. We will be generating 5k images and using a 90:10 split for training and validation.

# %%
# Once the data generation is complete, list the folders in the data directory

# !ls -rlt $MOUNT_DIR/palletjack_data

# There hould be 3 folders -> 1. distractors_warehouse 2. distractors_additional 3. no_distractors
# Out:
# total 12
# drwxrwxr-x 3 elliemcintosh elliemcintosh 4096 May  6 16:45 distractors_warehouse
# drwxr-xr-x 3 root          root          4096 May  8 05:47 distractors_additional
# drwxr-xr-x 3 root          root          4096 May  8 06:10 no_distractors

# %%
# !ls ~/Documents/synthetic_data_generation_training_workflow/palletjack_sdg/palletjack_data

# inspect generated dataset: 
# find ~/Documents/synthetic_data_generation_training_workflow/palletjack_sdg/palletjack_data -type f | head -20
# check dataset size
# du -sh ~/Documents/synthetic_data_generation_training_workflow/palletjack_sdg/palletjack_data
# Out:
# distractors_additional	distractors_warehouse  no_distractors

# %% [markdown]
# ## 3. Deeper Dive into SDG Script  <a class="anchor" id="head-3"></a>
#
# * The `standalone_palletjack_sdg.py` is the Python script which runs and generates data in headless mode inside the container.
# * The overall flow of the script is similar to the `standalone_examples/replicator/offline_generation.py` file provided as a starting point with Isaac Sim
#
#
# * We will be carrying out specific randomizations targeted to our use case. Some of them are:
#     * Camera Pose Randomization -> Should be similar to a robot perspective in the scene
#     * Palletjack Color Randomization -> To ensure model is robust to variations in Palletjack colors
#     * Distractors Pose Randomization -> To enable the model to *focus* on the right object (Our object of interest: Palletjack)
#     * Lighting Randomization-> Model robust to lights and reflections/shadows in the scene
#     * Floor and Wall Texture Randomization -> Model more robust to changes in background textures and features <br> <br>
#
#
# * We are only interested in the `palletjack` object class, all other semantics are removed from the stage with the `update_semantics()` function
#
# * You can use a model of your own choice to train with this data (Pytorch/Tensorflow or other frameworks)
#
# * The data is written in the KITTI Format, this allows seamless integration with TAO to train a model. Refer to `training/cloud_train.ipynb` notebook (Part 2) for training with TAO
